# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'].str.replace('GB', ' ')
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#        ...
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB', ' ')

# %%
df['Weight'] = df['Weight'].str.replace('kg', ' ')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
  new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].astype('int32')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(2), int64(2), object(8)
# ...

# %%
df['Y_res'] = df['Y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
print('df.types')
# Out:
# df.types

# %%
print(df.dtypes)
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int32
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float32
# Price               float64
# Touchscreen           int64
# IPS                   int64
# X_res                 int32
# Y_res                 int32
# ppi                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  ppi               1303 non-null   float64
# ...

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches', 'X_res', 'Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
def fetch_proccesor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(fetch_proccesor)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df.sample()
# Out:
#      Company            TypeName                           ScreenResolution  \
# 1219    Acer  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 1219  Intel Core i7 7Y75 1.3GHz    8  256GB SSD  Intel HD Graphics 615
#
#            OpSys  Weight     Price  Touchscreen  IPS         ppi  \
# 1219  Windows 10     1.2  61218.72            1    1  157.350512
#
#            Cpu Name      Cpu Brand
# 1219  Intel Core i7  Intel Core i7

# %%
df.sample()
# Out:
#     Company  TypeName ScreenResolution                         Cpu  Ram  \
# 965    Dell  Notebook         1366x768  Intel Core i3 6006U 2.0GHz    4
#
#       Memory                 Gpu  OpSys  Weight       Price  Touchscreen  IPS  \
# 965  1TB HDD  AMD Radeon R5 M430  Linux    2.25  24808.2336            0    0
#
#            ppi       Cpu Name      Cpu Brand
# 965  100.45467  Intel Core i3  Intel Core i3

# %%
print(df[df['Cpu Brand'] == 'AMD Processor'])
# Out:
#      Company  TypeName   ScreenResolution                           Cpu  Ram  \
# 5       Acer  Notebook           1366x768       AMD A9-Series 9420 3GHz    4
# 22        HP  Notebook           1366x768  AMD E-Series E2-9000e 1.5GHz    4
# 31      Asus  Notebook           1366x768   AMD E-Series E2-6110 1.5GHz    2
# 32        HP  Notebook  Full HD 1920x1080     AMD A6-Series 9220 2.5GHz    4
# 47      Asus    Gaming  Full HD 1920x1080           AMD Ryzen 1700 3GHz    8
# ...      ...       ...                ...                           ...  ...
# 1240  Lenovo  Notebook  Full HD 1920x1080   AMD A12-Series 9720P 3.6GHz    6
# 1251      HP  Notebook           1366x768     AMD A6-Series 9220 2.5GHz    4
# 1266      HP  Notebook  Full HD 1920x1080     AMD A9-Series 9410 2.9GHz    6
# 1280      HP  Notebook  Full HD 1920x1080     AMD A9-Series 9410 2.9GHz    6
# 1294      HP  Notebook  Full HD 1920x1080     AMD A9-Series 9410 2.9GHz    6
#
# ...

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
# df['Display'].value_counts().plot(kind='bar')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   ScreenResolution  1303 non-null   object
#  3   Cpu               1303 non-null   object
#  4   Ram               1303 non-null   int32
#  5   Memory            1303 non-null   object
#  6   Gpu               1303 non-null   object
#  7   OpSys             1303 non-null   object
#  8   Weight            1303 non-null   float32
#  9   Price             1303 non-null   float64
#  10  Touchscreen       1303 non-null   int64
#  11  IPS               1303 non-null   int64
#  12  ppi               1303 non-null   float64
#  13  Cpu Name          1303 non-null   object
#  14  Cpu Brand         1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df['Cpu'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Cpu'>

# %%
df['Cpu'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Cpu'>

# %%
df['Cpu'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
df.plot(kind='scatter', x='Price', y='ppi')
# Out:
# <Axes: xlabel='Price', ylabel='ppi'>

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   ScreenResolution  1303 non-null   object
#  3   Cpu               1303 non-null   object
#  4   Ram               1303 non-null   int32
#  5   Memory            1303 non-null   object
#  6   Gpu               1303 non-null   object
#  7   OpSys             1303 non-null   object
#  8   Weight            1303 non-null   float32
#  9   Price             1303 non-null   float64
#  10  Touchscreen       1303 non-null   int64
#  11  IPS               1303 non-null   int64
#  12  ppi               1303 non-null   float64
#  13  Cpu Name          1303 non-null   object
#  14  Cpu Brand         1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df.drop(columns=['Cpu', 'Cpu Name'])
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df['ppi'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ppi'>

# %%
# Step 1: Clean the 'Memory' column (remove .0, GB, and convert TB to 000 GB)
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')

# Step 2: Split into two layers (some laptops have 2 memory types, like SSD+HDD)
new = df['Memory'].str.split('+', n=1, expand=True)
df['first'] = new[0].str.strip()
df['second'] = new[1].fillna("0")

# Step 3: Create indicator columns for memory types in 'first' layer
df['Layer1HDD'] = df['first'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 4: Remove non-digit characters (keep only numbers)
df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# Step 5: Create indicator columns for memory types in 'second' layer
df['Layer2HDD'] = df['second'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 6: Remove non-digit characters from second layer as well
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# Step 7: Convert cleaned memory size strings to integers
df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)

# Step 8: Compute final columns for each storage type
df['HDD'] = (df['first'] * df['Layer1HDD']) + (df['second'] * df['Layer2HDD'])
df['SSD'] = (df['first'] * df['Layer1SSD']) + (df['second'] * df['Layer2SSD'])
df['Hybrid'] = (df['first'] * df['Layer1Hybrid']) + (df['second'] * df['Layer2Hybrid'])
df['Flash_Storage'] = (df['first'] * df['Layer1Flash_Storage']) + (df['second'] * df['Layer2Flash_Storage'])

# Step 9: Drop intermediate columns to clean up the DataFrame
df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\2792941849.py:2: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# %%
df.sample(5)
# Out:
#      Company  TypeName   ScreenResolution                         Cpu  Ram  \
# 544     Asus  Notebook           1366x768    AMD E-Series 7110 1.8GHz    4
# 1012      HP  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    4
# 497       HP  Notebook  Full HD 1920x1080  Intel Core i7 7600U 2.8GHz    8
# 60      Dell  Notebook  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz   16
# 625   Lenovo  Notebook  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz    8
#
#                    Memory                     Gpu       OpSys  Weight  \
# 544               500 HDD  AMD Radeon R2 Graphics  Windows 10    2.00
# 1012              256 SSD   Intel HD Graphics 620  Windows 10    1.48
# 497              1000 SSD   Intel HD Graphics 620  Windows 10    1.48
# 60    256 SSD +  2000 HDD          AMD Radeon 530  Windows 10    2.80
# 625              1000 HDD    Nvidia GeForce 920MX  Windows 10    2.20
#
#          Price  Touchscreen  IPS         ppi           Cpu Name  \
# ...

# %%
# Step 1: Clean up 'Memory' column
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')
df['Memory'] = df['Memory'].str.strip()

# Step 2: Split on '+' (for dual memory storage types like '128 SSD + 1TB HDD')
new = df['Memory'].str.split('+', n=1, expand=True)

# Step 3: Create 'first' and 'second' memory parts
df['first'] = new[0]
df['second'] = new[1]

# Step 4: Handle missing values (if any second memory is not there)
df['first'] = df['first'].fillna("0")
df['second'] = df['second'].fillna("0")

# Step 5: Create binary flags for each memory type
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 6: Remove non-digit characters and convert to integers
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

df['first'] = df['first'].fillna("0").astype(int)
df['second'] = df['second'].fillna("0").astype(int)

# Step 7: Final storage features in GB
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# Step 8: Drop intermediate columns
df.drop(columns=['first', 'second',
                 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
                 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram             Memory  \
# 0        Intel Core i5 2.3GHz    8            128 SSD
# 1        Intel Core i5 1.8GHz    8  128 Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256 SSD
# 3        Intel Core i7 2.7GHz   16            512 SSD
# 4        Intel Core i5 3.1GHz    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df.sample(4)
# Out:
#       Company            TypeName                 ScreenResolution  \
# 1221      MSI              Gaming                Full HD 1920x1080
# 557    Lenovo            Notebook                         1600x900
# 1133       HP           Ultrabook                Full HD 1920x1080
# 771   Samsung  2 in 1 Convertible  Full HD / Touchscreen 1920x1080
#
#                               Cpu  Ram               Memory  \
# 1221  Intel Core i7 6700HQ 2.6GHz    8  128 SSD +  1000 HDD
# 557    Intel Core i7 7500U 2.7GHz    6  128 SSD +  1000 HDD
# 1133   Intel Core i7 7500U 2.7GHz    8              256 SSD
# 771    Intel Core i7 7500U 2.7GHz   16              256 SSD
#
#                           Gpu       OpSys  Weight       Price  Touchscreen  \
# 1221  Nvidia GeForce GTX 1060  Windows 10    2.20  78647.1408            0
# 557      Nvidia GeForce 940MX  Windows 10    2.80  50562.7200            0
# 1133    Intel HD Graphics 620  Windows 10    1.84  40066.5600            0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS         ppi       Cpu Name  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5
# ...

# %%
df.drop(columns=['Cpu'])
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df.sample(9)
# Out:
#      Company            TypeName                           ScreenResolution  \
# 920     Dell            Notebook                                   1366x768
# 680      MSI              Gaming                          Full HD 1920x1080
# 1260  Lenovo  2 in 1 Convertible            Full HD / Touchscreen 1920x1080
# 1022      HP            Notebook                IPS Panel Full HD 1920x1080
# 541     Dell            Notebook                          Full HD 1920x1080
# 244   Lenovo  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 304     Asus              Gaming                          Full HD 1920x1080
# 1076  Lenovo            Notebook                IPS Panel Full HD 1920x1080
# 409   Lenovo            Notebook                                   1366x768
#
#                                        Cpu  Ram                         Gpu  \
# 920             Intel Core i5 7200U 2.5GHz    4          AMD Radeon R5 M420
# ...

# %%
df.sample(9)
# Out:
#      Company            TypeName                            ScreenResolution  \
# 522     Dell            Notebook                           Full HD 1920x1080
# 884     Dell            Notebook                                    1366x768
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 395       HP           Ultrabook                           Full HD 1920x1080
# 1057    Acer            Notebook                                    1366x768
# 405     Asus           Ultrabook                           Full HD 1920x1080
# 427     Dell           Ultrabook                           Full HD 1920x1080
# 977     Asus  2 in 1 Convertible         4K Ultra HD / Touchscreen 3840x2160
# 1209    Asus              Gaming                           Full HD 1920x1080
#
#                                        Cpu  Ram                      Gpu  \
# 522             Intel Core i5 7300U 2.6GHz    8    Intel HD Graphics 620
# ...

# %%
df.sample(5)
# Out:
#     Company   TypeName                            ScreenResolution  \
# 562      HP  Ultrabook  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 498  Lenovo   Notebook                 IPS Panel Full HD 1920x1080
# 392    Acer   Notebook                          IPS Panel 1366x768
# 527  Lenovo   Notebook                                    1366x768
# 288  Lenovo     Gaming                 IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                         Gpu       OpSys  \
# 562     Intel Core M 6Y75 1.2GHz   16       Intel HD Graphics 515  Windows 10
# 498   Intel Core i3 7100U 2.4GHz    8       Intel HD Graphics 620  Windows 10
# 392   Intel Core i5 8250U 1.6GHz   12        Nvidia GeForce MX130  Windows 10
# 527     Intel Core i3 6006U 2GHz    8       Nvidia GeForce 920MX        No OS
# 288  Intel Core i7 7700HQ 2.8GHz   16  Nvidia GeForce GTX 1050 Ti  Windows 10
#
#      Weight        Price  Touchscreen  IPS         ppi       Cpu Name  \
# ...

# %%
df.sample(99)
# Out:
#        Company   TypeName             ScreenResolution  \
# 321     Lenovo   Notebook                     1600x900
# 781       Asus     Gaming  IPS Panel Full HD 1920x1080
# 107       Asus  Ultrabook  IPS Panel Full HD 1920x1080
# 506       Asus   Notebook            Full HD 1920x1080
# 163     Lenovo     Gaming  IPS Panel Full HD 1920x1080
# ...        ...        ...                          ...
# 396     Lenovo   Notebook  IPS Panel Full HD 1920x1080
# 505     Lenovo   Notebook            Full HD 1920x1080
# 580   Mediacom   Notebook  IPS Panel Full HD 1920x1080
# 1046        HP   Notebook            Full HD 1920x1080
# 1252    Lenovo   Notebook            Full HD 1920x1080
#
#                                        Cpu  Ram                         Gpu  \
# 321             Intel Core i5 7200U 2.5GHz    4        Nvidia GeForce 920MX
# 781            Intel Core i7 6700HQ 2.6GHz   16     Nvidia GeForce GTX 1070
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS         ppi       Cpu Name  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5
# ...

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS         ppi       Cpu Name  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5
# ...

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz    8  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz    8        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz    8         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz   16            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS         ppi       Cpu Name  \
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5
# ...

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1302 non-null   object
#  1   TypeName          1302 non-null   object
#  2   ScreenResolution  1302 non-null   object
#  3   Cpu               1302 non-null   object
#  4   Ram               1302 non-null   int32
#  5   Gpu               1302 non-null   object
#  6   OpSys             1302 non-null   object
#  7   Weight            1302 non-null   float32
#  8   Price             1302 non-null   float64
#  9   Touchscreen       1302 non-null   int64
#  10  IPS               1302 non-null   int64
#  11  ppi               1302 non-null   float64
#  12  Cpu Name          1302 non-null   object
#  13  Cpu Brand         1302 non-null   object
#  14  HDD               1302 non-null   int64
#  15  SSD               1302 non-null   int64
# ...

# %%
df['Gpu Brand'] = df['Gpu Brand'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df['Gpu Brand'] = df['Gpu Brand'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
sns.barplot(x=df['Gpu Brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1302 non-null   object
#  1   TypeName          1302 non-null   object
#  2   ScreenResolution  1302 non-null   object
#  3   Cpu               1302 non-null   object
#  4   Ram               1302 non-null   int32
#  5   OpSys             1302 non-null   object
#  6   Weight            1302 non-null   float32
#  7   Price             1302 non-null   float64
#  8   Touchscreen       1302 non-null   int64
#  9   IPS               1302 non-null   int64
#  10  ppi               1302 non-null   float64
#  11  Cpu Name          1302 non-null   object
#  12  Cpu Brand         1302 non-null   object
#  13  HDD               1302 non-null   int64
#  14  SSD               1302 non-null   int64
#  15  Gpu Brand         1302 non-null   object
# ...

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram  OpSys  Weight        Price  Touchscreen  \
# 0        Intel Core i5 2.3GHz    8  macOS    1.37   71378.6832            0
# 1        Intel Core i5 1.8GHz    8  macOS    1.34   47895.5232            0
# 2  Intel Core i5 7200U 2.5GHz    8  No OS    1.86   30636.0000            0
# 3        Intel Core i7 2.7GHz   16  macOS    1.83  135195.3360            0
# 4        Intel Core i5 3.1GHz    8  macOS    1.37   96095.8080            0
#
#    IPS         ppi       Cpu Name      Cpu Brand  HDD  SSD Gpu Brand
# 0    1  226.983005  Intel Core i5  Intel Core i5    0  128     Intel
# ...

# %%
df['OpSys'].value_counts().plot()
# Out:
# <Axes: xlabel='OpSys'>

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\3648919379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram  OpSys  Weight        Price  Touchscreen  \
# 0        Intel Core i5 2.3GHz    8  macOS    1.37   71378.6832            0
# 1        Intel Core i5 1.8GHz    8  macOS    1.34   47895.5232            0
# 2  Intel Core i5 7200U 2.5GHz    8  No OS    1.86   30636.0000            0
# 3        Intel Core i7 2.7GHz   16  macOS    1.83  135195.3360            0
# 4        Intel Core i5 3.1GHz    8  macOS    1.37   96095.8080            0
#
#    IPS         ppi       Cpu Name      Cpu Brand  HDD  SSD Gpu Brand  \
# 0    1  226.983005  Intel Core i5  Intel Core i5    0  128     Intel
# ...

# %%
df.drop(columns=['OpSys'], inplace=True)
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\2632010566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram  Weight        Price  Touchscreen  IPS  \
# 0        Intel Core i5 2.3GHz    8    1.37   71378.6832            0    1
# 1        Intel Core i5 1.8GHz    8    1.34   47895.5232            0    0
# 2  Intel Core i5 7200U 2.5GHz    8    1.86   30636.0000            0    0
# 3        Intel Core i7 2.7GHz   16    1.83  135195.3360            0    1
# 4        Intel Core i5 3.1GHz    8    1.37   96095.8080            0    1
#
#           ppi       Cpu Name      Cpu Brand  HDD  SSD Gpu Brand  \
# 0  226.983005  Intel Core i5  Intel Core i5    0  128     Intel
# ...

# %%
df.drop(columns=['Cpu', 'Cpu Name'], inplace=True)
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\2697900877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Cpu', 'Cpu Name'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  Weight  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8    1.37
# 1   Apple  Ultrabook                            1440x900    8    1.34
# 2      HP   Notebook                   Full HD 1920x1080    8    1.86
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16    1.83
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand                  os
# 0     Intel                 Mac
# 1     Intel                 Mac
# ...

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.select_dtypes(include='number').corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
df_numeric = df.select_dtypes(include='number')
print(df_numeric.columns)  # check which columns are numeric

corr_matrix = df_numeric.corr()
print(corr_matrix['Price'])  # correlations with Price
# Out:
# Index(['Ram', 'Weight', 'Price', 'Touchscreen', 'IPS', 'ppi', 'HDD', 'SSD'], dtype='object')
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
# Select numeric columns only
df_numeric = df.select_dtypes(include='number')

# Calculate correlation matrix
corr_matrix = df_numeric.corr()

# Display the full matrix
print(corr_matrix)
# Out:
#                   Ram    Weight     Price  Touchscreen       IPS       ppi  \
# Ram          1.000000  0.383362  0.742905     0.118875  0.207949  0.305688
# Weight       0.383362  1.000000  0.209867    -0.293004  0.018643 -0.321883
# Price        0.742905  0.209867  1.000000     0.192917  0.253320  0.475368
# Touchscreen  0.118875 -0.293004  0.192917     1.000000  0.148026  0.458571
# IPS          0.207949  0.018643  0.253320     0.148026  1.000000  0.299142
# ppi          0.305688 -0.321883  0.475368     0.458571  0.299142  1.000000
# HDD          0.095808  0.514147 -0.096891    -0.208766 -0.093588 -0.294698
# SSD          0.603379 -0.063818  0.670660     0.257577  0.225311  0.509437
#
#                   HDD       SSD
# Ram          0.095808  0.603379
# Weight       0.514147 -0.063818
# Price       -0.096891  0.670660
# Touchscreen -0.208766  0.257577
# IPS         -0.093588  0.225311
# ppi         -0.294698  0.509437
# HDD          1.000000 -0.400750
# ...

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
X
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
# ...

# %%
y_train
# Out:
# 183     10.651384
# 1141    11.016798
# 1049     9.638174
# 1020    10.655148
# 878     10.791749
#           ...
# 466     10.126164
# 299     11.267217
# 493     10.336864
# 527     10.104611
# 1193    11.034319
# Name: Price, Length: 1106, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
from sklearn.svm import SVR

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  Weight  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8    1.37
# 1   Apple  Ultrabook                            1440x900    8    1.34
# 2      HP   Notebook                   Full HD 1920x1080    8    1.86
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16    1.83
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu Brand                  os
# 0     Intel                 Mac
# 1     Intel                 Mac
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1302 non-null   object
#  1   TypeName          1302 non-null   object
#  2   ScreenResolution  1302 non-null   object
#  3   Ram               1302 non-null   int32
#  4   Weight            1302 non-null   float32
#  5   Price             1302 non-null   float64
#  6   Touchscreen       1302 non-null   int64
#  7   IPS               1302 non-null   int64
#  8   ppi               1302 non-null   float64
#  9   Cpu Brand         1302 non-null   object
#  10  HDD               1302 non-null   int64
#  11  SSD               1302 non-null   int64
#  12  Gpu Brand         1302 non-null   object
#  13  os                1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(6)
# memory usage: 142.4+ KB

# %%
X
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 18
#      11 step2 = LinearRegression()
#      13 pipe = Pipeline([
#      14     ('step1', step1),
#      15     ('step2', step2)
#      16 ])
# ---> 18 pipe.fit(X_train, y_train)
#      19 y_pred = pipe.predict(X_test)
#      21 print('R2 score', r2_score(y_test, y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:473, in Pipeline.fit(self, X, y, **params)
# ...

# %%
df.head()

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_5600\840532398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 18
#      11 step2 = LinearRegression()
#      13 pipe = Pipeline([
#      14     ('step1', step1),
#      15     ('step2', step2)
#      16 ])
# ---> 18 pipe.fit(X_train, y_train)
#      19 y_pred = pipe.predict(X_test)
#      21 print('R2 score', r2_score(y_test, y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:473, in Pipeline.fit(self, X, y, **params)
# ...

# %%
print(X_train.info())
print(X_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1106 entries, 183 to 1193
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1106 non-null   object
#  1   TypeName          1106 non-null   object
#  2   ScreenResolution  1106 non-null   object
#  3   Ram               1106 non-null   int32
#  4   Weight            1106 non-null   float32
#  5   Touchscreen       1106 non-null   int64
#  6   IPS               1106 non-null   int64
#  7   ppi               1106 non-null   float64
#  8   Cpu Brand         1106 non-null   object
#  9   HDD               1106 non-null   int64
#  10  SSD               1106 non-null   int64
#  11  Gpu Brand         1106 non-null   object
#  12  os                1106 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(4), object(6)
# memory usage: 112.3+ KB
# None
# Company             0
# TypeName            0
# ScreenResolution    0
# ...

# %% [markdown]
# ### LINEAR REGRESSION

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# Define categorical columns
# cat_columns = ['Company', 'TypeName', 'ScreenResolution', 'Cpu Brand', 'Gpu Brand', 'os']

# ColumnTransformer: OneHotEncode categorical, pass through numeric
step1 = ColumnTransformer(transformers=[
    ('cat_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), 
     ['Company', 'TypeName', 'ScreenResolution', 'Cpu Brand', 'Gpu Brand', 'os'])
], remainder='passthrough')
  # numeric columns are passed as-is

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8113246369041821
# MAE: 0.21277794243412038
# C:\Users\bhard\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### RIDGE LASSO

# %%
step1 = ColumnTransformer(transformers=[
    ('cat_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), 
     ['Company', 'TypeName', 'ScreenResolution', 'Cpu Brand', 'Gpu Brand', 'os'])
], remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8148106970590171
# MAE 0.209481258209266
# C:\Users\bhard\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ###  RANDOM FOREST

# %%
step1 = ColumnTransformer(transformers=[
    ('cat_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), 
     ['Company', 'TypeName', 'ScreenResolution', 'Cpu Brand', 'Gpu Brand', 'os'])
], remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8869134153504024
# MAE 0.1568345587433338
# C:\Users\bhard\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
import pickle

# %%
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName                           ScreenResolution  \
# 183   Toshiba            Notebook                                   1366x768
# 1141      MSI              Gaming                          Full HD 1920x1080
# 1049     Asus             Netbook                                   1366x768
# 1020     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 878      Dell            Notebook                          Full HD 1920x1080
# ...       ...                 ...                                        ...
# 466      Acer            Notebook                                   1366x768
# 299      Asus           Ultrabook                          Full HD 1920x1080
# 493      Acer            Notebook                                   1366x768
# 527    Lenovo            Notebook                                   1366x768
# 1193    Apple           Ultrabook         IPS Panel Retina Display 2304x1440
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\bhard\anaconda_projects\b91e5de3-ffc9-47c6-8f26-9016224536dc

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: C:\Users\bhard\anaconda3\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: imbalanced-learn
# Note: you may need to restart the kernel to use updated packages.

# %%
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df.info
# Out:
# <bound method DataFrame.info of      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...
